# %%
import matplotlib.pyplot as plt
from rdkit import Chem
from rdkit.Chem.AllChem import GetMorganFingerprint
from rdkit.Chem.Draw import DrawMorganBit

# %%
mol = Chem.MolFromMolFile('pahdb_mol/495.mol')
mol

# %%
bi = {}
ecfp = GetMorganFingerprint(mol, radius=2, bitInfo=bi, useFeatures=False, useBondTypes=False)
# 由于openbabel无法准确判断键的类型，须设置 useBondTypes=False

col = 5
row = (len(bi) - 1) // col + 1
fig, axes = plt.subplots(row, col, figsize=(col * 3, row * 3), tight_layout=True)
for ax in axes.ravel():
    ax.axis('off')
for ax, bit in zip(axes.ravel(), bi.keys()):
    ax.imshow(DrawMorganBit(mol, bit, bi))
#     ax.set_title(bit)

# %%
bi
# Out:
# {98467359: ((6, 1), (7, 1)),
#  739908201: ((0, 2), (1, 2)),
#  951238370: ((5, 1), (8, 1)),
#  1357978105: ((4, 2), (2, 2)),
#  2070976054: ((2, 1), (4, 1)),
#  2288476549: ((3, 2),),
#  2361036403: ((0, 1), (1, 1)),
#  2968968094: ((3, 0),),
#  3217380708: ((0, 0), (1, 0)),
#  3218693969: ((2, 0), (4, 0), (5, 0), (6, 0), (7, 0), (8, 0)),
#  3863378982: ((6, 2), (7, 2)),
#  4101374036: ((5, 2), (8, 2)),
#  4124481675: ((3, 1),)}
